# %%
import matplotlib.pyplot as plt
import numpy as np

# 生成数据
x = np.arange(1, 10001)
y = 12000 * np.exp(-x / 2000)

# 绘制折线图
plt.plot(x, y)

# 添加坐标轴标签
plt.xlabel('subsets')
plt.ylabel('iterations')

# 显示图像
plt.show()
